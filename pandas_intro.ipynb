# %%
import os 
import pandas as pd
import numpy as np

# %%
csvPathFile = os.path.join(os.getcwd(), 'roster.csv')
print(csvPathFile)
# Out:
# /Users/milesstevens/Documents/GitHub/helloworld/roster.csv

# %% [markdown]
# ### Read CSV to DataFrame

# %%
roster = pd.read_csv(csvPathFile)
print(type(roster))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %% [markdown]
# #### Viewing the data

# %%
roster.head()
# Out:
#         name
# 0        Joe
# 1     Jihuan
# 2        Ali
# 3    Frances
# 4  Daniela V

# %%
roster
# Out:
#          name
# 0         Joe
# 1      Jihuan
# 2         Ali
# 3     Frances
# 4   Daniela V
# 5     Mostafa
# 6   Daniela P
# 7       Cesar
# 8      Jarrod
# 9      Austin
# 10       Jack
# 11        Ala
# 12     Sergii
# 13      Miles
# 14     Hyeyun
# 15  Volodymyr
# 16      Yijia
# 17   Hsin-Yun
# 18     Renata
# 19        Max
# 20     Joshua
# 21      David

# %% [markdown]
# ### Modifying the Data

# %%
d = {'name': ['Wally']}
tmp_df = pd.DataFrame(data=d)
tmp_df
# Out:
#     name
# 0  Wally

# %%
d = {'name': ['Wally']}
tmp_df = pd.DataFrame(data=d)
roster = pd.concat([roster, tmp_df], ignore_index=True)
roster
# Out:
#          name
# 0         Joe
# 1      Jihuan
# 2         Ali
# 3     Frances
# 4   Daniela V
# 5     Mostafa
# 6   Daniela P
# 7       Cesar
# 8      Jarrod
# 9      Austin
# 10       Jack
# 11        Ala
# 12     Sergii
# 13      Miles
# 14     Hyeyun
# 15  Volodymyr
# 16      Yijia
# 17   Hsin-Yun
# 18     Renata
# 19        Max
# 20     Joshua
# 21      David
# 22      Wally

# %% [markdown]
# #### Assign Grades

# %%
roster['grade'] = 70
roster
# Out:
#          name  grade
# 0         Joe     70
# 1      Jihuan     70
# 2         Ali     70
# 3     Frances     70
# 4   Daniela V     70
# 5     Mostafa     70
# 6   Daniela P     70
# 7       Cesar     70
# 8      Jarrod     70
# 9      Austin     70
# 10       Jack     70
# 11        Ala     70
# 12     Sergii     70
# 13      Miles     70
# 14     Hyeyun     70
# 15  Volodymyr     70
# 16      Yijia     70
# 17   Hsin-Yun     70
# 18     Renata     70
# 19        Max     70
# 20     Joshua     70
# 21      David     70
# 22      Wally     70

# %%
import random
roster['grade'] = random.randint(0,100)
roster
# Out:
#          name  grade
# 0         Joe     79
# 1      Jihuan     79
# 2         Ali     79
# 3     Frances     79
# 4   Daniela V     79
# 5     Mostafa     79
# 6   Daniela P     79
# 7       Cesar     79
# 8      Jarrod     79
# 9      Austin     79
# 10       Jack     79
# 11        Ala     79
# 12     Sergii     79
# 13      Miles     79
# 14     Hyeyun     79
# 15  Volodymyr     79
# 16      Yijia     79
# 17   Hsin-Yun     79
# 18     Renata     79
# 19        Max     79
# 20     Joshua     79
# 21      David     79
# 22      Wally     79

# %%
np.random.seed(1)
np.random.randint(0,100, size =len(roster))
# Out:
# array([37, 12, 72,  9, 75,  5, 79, 64, 16,  1, 76, 71,  6, 25, 50, 20, 18,
#        84, 11, 28, 29, 14, 50])

# %%
np.random.seed(1)
roster['grade']= np.random.randint(0,100, size =len(roster))
roster
# Out:
#          name  grade
# 0         Joe     37
# 1      Jihuan     12
# 2         Ali     72
# 3     Frances      9
# 4   Daniela V     75
# 5     Mostafa      5
# 6   Daniela P     79
# 7       Cesar     64
# 8      Jarrod     16
# 9      Austin      1
# 10       Jack     76
# 11        Ala     71
# 12     Sergii      6
# 13      Miles     25
# 14     Hyeyun     50
# 15  Volodymyr     20
# 16      Yijia     18
# 17   Hsin-Yun     84
# 18     Renata     11
# 19        Max     28
# 20     Joshua     29
# 21      David     14
# 22      Wally     50

# %% [markdown]
# .loc can be used with a boolean array (i.e. of 1s and 0s)

# %%
roster['name'] == "Daniela P"
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6      True
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# Name: name, dtype: bool

# %%
roster.loc[roster['name'] == 'Daniela P', 'grade'] = 100
roster
# Out:
#          name  grade
# 0         Joe     37
# 1      Jihuan     12
# 2         Ali     72
# 3     Frances      9
# 4   Daniela V     75
# 5     Mostafa      5
# 6   Daniela P    100
# 7       Cesar     64
# 8      Jarrod     16
# 9      Austin      1
# 10       Jack     76
# 11        Ala     71
# 12     Sergii      6
# 13      Miles     25
# 14     Hyeyun     50
# 15  Volodymyr     20
# 16      Yijia     18
# 17   Hsin-Yun     84
# 18     Renata     11
# 19        Max     28
# 20     Joshua     29
# 21      David     14
# 22      Wally     50

# %% [markdown]
# ### Check the class average
#
# Each column pandas dataframe is a series object -- which have dozens of built-in methods

# %%
roster['grade'].mean()
# Out:
# 37.95652173913044

# %%
roster.loc[roster['grade'] < 50, 'grade']= roster['grade'] + 40
roster
# Out:
#          name  grade
# 0         Joe     77
# 1      Jihuan     52
# 2         Ali     72
# 3     Frances     49
# 4   Daniela V     75
# 5     Mostafa     45
# 6   Daniela P    100
# 7       Cesar     64
# 8      Jarrod     56
# 9      Austin     41
# 10       Jack     76
# 11        Ala     71
# 12     Sergii     46
# 13      Miles     65
# 14     Hyeyun     50
# 15  Volodymyr     60
# 16      Yijia     58
# 17   Hsin-Yun     84
# 18     Renata     51
# 19        Max     68
# 20     Joshua     69
# 21      David     54
# 22      Wally     50

# %%
roster['grade'].mean()
# Out:
# 62.30434782608695

# %%
roster['grade'] = roster['grade'] + 13

# %%
roster['grade'].mean()
# Out:
# 75.30434782608695

# %% [markdown]
# ### Write to CSV

# %%
outFilePath = os.path.join(os.getcwd(), 'roster_pandas.csv')
print(outFilePath)
# Out:
# /Users/milesstevens/Documents/GitHub/helloworld/roster_pandas.csv

# %%
roster.to_csv(outFilePath, index=False)

# %% [markdown]
# ### More Aggregation and Manipulation

# %%
np.random.seed(2)
np.random.choice(['red', 'blue'], size=len(roster))
# Out:
# array(['red', 'blue', 'blue', 'red', 'red', 'blue', 'red', 'blue', 'red',
#        'blue', 'red', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue',
#        'blue', 'red', 'red', 'red', 'red', 'blue'], dtype='<U4')

# %%
roster['group'] = np.random.choice(['red','blue'], size = len(roster))
roster
# Out:
#          name  grade group
# 0         Joe     90  blue
# 1      Jihuan     65  blue
# 2         Ali     85   red
# 3     Frances     62   red
# 4   Daniela V     88   red
# 5     Mostafa     58  blue
# 6   Daniela P    113  blue
# 7       Cesar     77  blue
# 8      Jarrod     69   red
# 9      Austin     54   red
# 10       Jack     89  blue
# 11        Ala     84   red
# 12     Sergii     59   red
# 13      Miles     78  blue
# 14     Hyeyun     63  blue
# 15  Volodymyr     73  blue
# 16      Yijia     71   red
# 17   Hsin-Yun     97   red
# 18     Renata     64   red
# 19        Max     81   red
# 20     Joshua     82  blue
# 21      David     67  blue
# 22      Wally     63  blue

# %%
group_means = roster.groupby(by=['group']).mean()
group_means
# Out:
#        grade
# group
# blue    76.5
# red     74.0

# %%
group_means.rename(columns={'grade': 'group_avg'}, inplace =True)
group_means
# Out:
#        group_avg
# group
# blue        76.5
# red         74.0

# %% [markdown]
# ### Merging DataFrames

# %%
print(roster.shape)
print(group_means.shape)
# Out:
# (23, 3)
# (2, 1)

# %%
roster = roster.merge(group_means, on=['group'])
roster.shape
# Out:
# (23, 4)

# %%
roster
# Out:
#          name  grade group  group_avg
# 0         Joe     90  blue       76.5
# 1      Jihuan     65  blue       76.5
# 2     Mostafa     58  blue       76.5
# 3   Daniela P    113  blue       76.5
# 4       Cesar     77  blue       76.5
# 5        Jack     89  blue       76.5
# 6       Miles     78  blue       76.5
# 7      Hyeyun     63  blue       76.5
# 8   Volodymyr     73  blue       76.5
# 9      Joshua     82  blue       76.5
# 10      David     67  blue       76.5
# 11      Wally     63  blue       76.5
# 12        Ali     85   red       74.0
# 13    Frances     62   red       74.0
# 14  Daniela V     88   red       74.0
# 15     Jarrod     69   red       74.0
# 16     Austin     54   red       74.0
# 17        Ala     84   red       74.0
# 18     Sergii     59   red       74.0
# 19      Yijia     71   red       74.0
# 20   Hsin-Yun     97   red       74.0
# 21     Renata     64   red       74.0
# 22        Max     81   red       74.0

# %% [markdown]
# ### Creating new columns from custom functions

# %%
def is_top50(col):
    return col > col.median()

# %%
roster['top50'] = roster[['grade']].apply(is_top50)

# %%
type(roster[['grade']])
# Out:
# pandas.core.frame.DataFrame

# %%
roster
# Out:
#          name  grade group  group_avg  top50
# 0         Joe     90  blue       76.5   True
# 1      Jihuan     65  blue       76.5  False
# 2     Mostafa     58  blue       76.5  False
# 3   Daniela P    113  blue       76.5   True
# 4       Cesar     77  blue       76.5   True
# 5        Jack     89  blue       76.5   True
# 6       Miles     78  blue       76.5   True
# 7      Hyeyun     63  blue       76.5  False
# 8   Volodymyr     73  blue       76.5  False
# 9      Joshua     82  blue       76.5   True
# 10      David     67  blue       76.5  False
# 11      Wally     63  blue       76.5  False
# 12        Ali     85   red       74.0   True
# 13    Frances     62   red       74.0  False
# 14  Daniela V     88   red       74.0   True
# 15     Jarrod     69   red       74.0  False
# 16     Austin     54   red       74.0  False
# 17        Ala     84   red       74.0   True
# 18     Sergii     59   red       74.0  False
# 19      Yijia     71   red       74.0  False
# 20   Hsin-Yun     97   red       74.0   True
# 21     Renata     64   red       74.0  False
# 22        Max     81   red       74.0   True

# %% [markdown]
# ### Creating new columns from custom functions
#
# By group

# %%
roster['top50_group'] = roster.groupby(by=['group'])[['grade']].apply(is_top50)
roster
# Out:
#          name  grade group  group_avg  top50  top50_group
# 0         Joe     90  blue       76.5   True         True
# 1      Jihuan     65  blue       76.5  False        False
# 2     Mostafa     58  blue       76.5  False        False
# 3   Daniela P    113  blue       76.5   True         True
# 4       Cesar     77  blue       76.5   True         True
# 5        Jack     89  blue       76.5   True         True
# 6       Miles     78  blue       76.5   True         True
# 7      Hyeyun     63  blue       76.5  False        False
# 8   Volodymyr     73  blue       76.5  False        False
# 9      Joshua     82  blue       76.5   True         True
# 10      David     67  blue       76.5  False        False
# 11      Wally     63  blue       76.5  False        False
# 12        Ali     85   red       74.0   True         True
# 13    Frances     62   red       74.0  False        False
# 14  Daniela V     88   red       74.0   True         True
# 15     Jarrod     69   red       74.0  False        False
# 16     Austin     54   red       74.0  False        False
# 17        Ala     84   red       74.0   True         True
# 18     Sergii     59   red       74.0  False        False
# 19      Yijia     71   red       74.0  False        False
# 20   Hsin-Yun     97   red       74.0   True         True
# 21     Renata     64   red       74.0  False        False
# 22        Max     81   red       74.0   True         True

# %% [markdown]
# ## Apply
#
# Apply can be used to invoke a function on
#
# 1. each value of a Series object
# 2. each column or index in a DataFrame object
# 3. each DataFrame in a GroupBy object

# %%
def print_arg(x):
    print(x)
    
def print_type(x):
    print(type(x))

# %% [markdown]
# ### pandas.Series.apply

# %%
grade_series = roster['grade']
print(type(grade_series))
# Out:
# <class 'pandas.core.series.Series'>

# %%
grade_series = roster['grade']
print(type(grade_series))
grade_series
# Out:
# <class 'pandas.core.series.Series'>
# 0      90
# 1      65
# 2      58
# 3     113
# 4      77
# 5      89
# 6      78
# 7      63
# 8      73
# 9      82
# 10     67
# 11     63
# 12     85
# 13     62
# 14     88
# 15     69
# 16     54
# 17     84
# 18     59
# 19     71
# 20     97
# 21     64
# 22     81
# Name: grade, dtype: int64

# %%
grade_series.apply(print_arg)
# Out:
# 90
# 65
# 58
# 113
# 77
# 89
# 78
# 63
# 73
# 82
# 67
# 63
# 85
# 62
# 88
# 69
# 54
# 84
# 59
# 71
# 97
# 64
# 81
# 0     None
# 1     None
# 2     None
# 3     None
# 4     None
# 5     None
# 6     None
# 7     None
# 8     None
# 9     None
# 10    None
# 11    None
# 12    None
# 13    None
# 14    None
# 15    None
# 16    None
# 17    None
# 18    None
# 19    None
# 20    None
# 21    None
# 22    None
# Name: grade, dtype: object

# %%
grade_series.apply(print_type)
# Out:
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# 0     None
# 1     None
# 2     None
# 3     None
# 4     None
# 5     None
# 6     None
# 7     None
# 8     None
# 9     None
# 10    None
# 11    None
# 12    None
# 13    None
# 14    None
# 15    None
# 16    None
# 17    None
# 18    None
# 19    None
# 20    None
# 21    None
# 22    None
# Name: grade, dtype: object

# %% [markdown]
# ## pandas.DataFrame.apply
#
# Apply a function to each row of the DataFrame (axis=1) or apply a function to each column of the data (axis).

# %%
grade_df = roster[['grade']]
print(type(grade_df))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
grade_df.apply(print_arg, axis=0)
# Out:
# 0      90
# 1      65
# 2      58
# 3     113
# 4      77
# 5      89
# 6      78
# 7      63
# 8      73
# 9      82
# 10     67
# 11     63
# 12     85
# 13     62
# 14     88
# 15     69
# 16     54
# 17     84
# 18     59
# 19     71
# 20     97
# 21     64
# 22     81
# Name: grade, dtype: int64
# grade    None
# dtype: object

# %%
grade_df.apply(print_type, axis=0)
# Out:
# <class 'pandas.core.series.Series'>
# grade    None
# dtype: object

# %%
grade_df.apply(print_type, axis=1)
# Out:
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>
# 0     None
# 1     None
# 2     None
# 3     None
# 4     None
# 5     None
# 6     None
# 7     None
# 8     None
# 9     None
# 10    None
# 11    None
# 12    None
# 13    None
# 14    None
# 15    None
# 16    None
# 17    None
# 18    None
# 19    None
# 20    None
# 21    None
# 22    None
# dtype: object

# %%
grade_df.apply(print_arg, axis=1)
# Out:
# grade    90
# Name: 0, dtype: int64
# grade    65
# Name: 1, dtype: int64
# grade    58
# Name: 2, dtype: int64
# grade    113
# Name: 3, dtype: int64
# grade    77
# Name: 4, dtype: int64
# grade    89
# Name: 5, dtype: int64
# grade    78
# Name: 6, dtype: int64
# grade    63
# Name: 7, dtype: int64
# grade    73
# Name: 8, dtype: int64
# grade    82
# Name: 9, dtype: int64
# grade    67
# Name: 10, dtype: int64
# grade    63
# Name: 11, dtype: int64
# grade    85
# Name: 12, dtype: int64
# grade    62
# Name: 13, dtype: int64
# grade    88
# Name: 14, dtype: int64
# grade    69
# Name: 15, dtype: int64
# grade    54
# Name: 16, dtype: int64
# grade    84
# Name: 17, dtype: int64
# grade    59
# Name: 18, dtype: int64
# grade    71
# Name: 19, dtype: int64
# grade    97
# Name: 20, dtype: int64
# grade    64
# Name: 21, dtype: int64
# grade    81
# Name: 22, dtype: int64
# 0     None
# 1     None
# 2     None
# 3     None
# 4     None
# 5     None
# 6     None
# 7     None
# 8     None
# 9     None
# 10    None
# 11    None
# 12    None
# 13    None
# 14    None
# 15    None
# 16    None
# 17    None
# 18    None
# 19    None
# 20    None
# 21    None
# 22    None
# dtype: object

# %% [markdown]
# ## DataFrameGroupBy

# %%
groups = roster.groupby(by=['group'])
print(type(groups))
groups
# Out:
# <class 'pandas.core.groupby.generic.DataFrameGroupBy'>

# %%
roster
# Out:
#          name  grade group  group_avg  top50
# 0         Joe     90  blue       76.5   True
# 1      Jihuan     65  blue       76.5  False
# 2     Mostafa     58  blue       76.5  False
# 3   Daniela P    113  blue       76.5   True
# 4       Cesar     77  blue       76.5   True
# 5        Jack     89  blue       76.5   True
# 6       Miles     78  blue       76.5   True
# 7      Hyeyun     63  blue       76.5  False
# 8   Volodymyr     73  blue       76.5  False
# 9      Joshua     82  blue       76.5   True
# 10      David     67  blue       76.5  False
# 11      Wally     63  blue       76.5  False
# 12        Ali     85   red       74.0   True
# 13    Frances     62   red       74.0  False
# 14  Daniela V     88   red       74.0   True
# 15     Jarrod     69   red       74.0  False
# 16     Austin     54   red       74.0  False
# 17        Ala     84   red       74.0   True
# 18     Sergii     59   red       74.0  False
# 19      Yijia     71   red       74.0  False
# 20   Hsin-Yun     97   red       74.0   True
# 21     Renata     64   red       74.0  False
# 22        Max     81   red       74.0   True

# %%
groups.apply(print_arg)
# Out:
#          name  grade group  group_avg  top50
# 0         Joe     90  blue       76.5   True
# 1      Jihuan     65  blue       76.5  False
# 2     Mostafa     58  blue       76.5  False
# 3   Daniela P    113  blue       76.5   True
# 4       Cesar     77  blue       76.5   True
# 5        Jack     89  blue       76.5   True
# 6       Miles     78  blue       76.5   True
# 7      Hyeyun     63  blue       76.5  False
# 8   Volodymyr     73  blue       76.5  False
# 9      Joshua     82  blue       76.5   True
# 10      David     67  blue       76.5  False
# 11      Wally     63  blue       76.5  False
#          name  grade group  group_avg  top50
# 12        Ali     85   red       74.0   True
# 13    Frances     62   red       74.0  False
# 14  Daniela V     88   red       74.0   True
# 15     Jarrod     69   red       74.0  False
# 16     Austin     54   red       74.0  False
# 17        Ala     84   red       74.0   True
# 18     Sergii     59   red       74.0  False
# 19      Yijia     71   red       74.0  False
# 20   Hsin-Yun     97   red       74.0   True
# 21     Renata     64   red       74.0  False
# 22        Max     81   red       74.0   True
# Empty DataFrame
# Columns: []
# Index: []

# %%
groups.apply(print_type)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# Empty DataFrame
# Columns: []
# Index: []
